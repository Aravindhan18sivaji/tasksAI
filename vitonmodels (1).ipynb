# %%
# # Install required libraries
# !pip install diffusers transformers accelerate datasets safetensors tensorboard

# # Clone TryOnDiffusion repo
# !git clone https://github.com/tryonlabs/tryondiffusion.git

# %cd tryondiffusion

# # Install TryOnDiffusion requirements
# !pip install -e .

# %%
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
# ...

# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install diffusers transformers accelerate
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 71.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 45.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 89.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.7 MB/s eta 0:00:00
# ...

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("gouthaml/raos-virtual-try-on-model")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/246M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.72k [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/346 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# ...

# %%
from PIL import Image

# %%
# Load the images
person_image = Image.open("/content/t-shirt.jpeg").convert("RGB")
cloth_image = Image.open("/content/image-wear.jpeg").convert("RGB")

# Generate the try-on result
result = pipe(person_image=person_image, clothing_image=cloth_image).images[0]

# Display the result
result.show()

# Save the generated image
result.save("output_tryon.jpg")

# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-105e1a41962e> in <cell line: 0>()
#       1 # Load the images
# ----> 2 person_image = Image.open("/content/t-shirt.jpeg").convert("RGB")
#       3 cloth_image = Image.open("/content/image-wear.jpeg").convert("RGB")
#       4
#       5 # Generate the try-on result

# NameError: name 'Image' is not defined
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-b1eaa40c7856> in <cell line: 0>()
#       4
#       5 # Generate the try-on result
# ----> 6 result = pipe(person_image=person_image, clothing_image=cloth_image).images[0]
#       7
#       8 # Display the result
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# ...

# %%
# Load input images
person_image = Image.open("/content/t-shirt.jpeg").convert("RGB")
cloth_image = Image.open("/content/image-wear.jpeg").convert("RGB")

# Define a try-on prompt
prompt = "Generate an image of the given person wearing the given cloth."

# Generate the try-on result
result = pipe(prompt=prompt, image=person_image, clothing_image=cloth_image).images[0]

# Display the result
result.show()

# Save the generated image
result.save("output_tryon.jpg")
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
pip install replicate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 2.1 MB/s eta 0:00:00
# ...

# %%
import os

# Set the API token
os.environ["REPLICATE_API_TOKEN"] = "r8_BdXFFKCIyogG2fPMpJH2n59WjwMzrrL2SPfYI"

# Verify it's set (without printing the actual token)
print("API token set successfully!" if "REPLICATE_API_TOKEN" in os.environ else "Failed to set API token")
# Out:
# API token set successfully!

# %%
import replicate

# %%
output = replicate.run(
    "mixinmax1990/realisitic-vision-v3-image-to-image:6eb633a82ab3e7a4417d0af2e84e24b4b419c76f86f6e837824d02ae6845dc81",
    input={
        "seed": 12,
        "image": "https://replicate.delivery/pbxt/J6aXwu9asvIjho0aW81BMCsXK0mNfqjHPJPSoJ4nCT1WWQbh/AdobeStock_506038307.jpeg",
        "prompt": "RAW photo, A Portrait of Rihanna , natural skin, 8k uhd, high quality, film grain, Fujifilm XT3, focus blur",
        "strength": 0.21,
        "negative_prompt": "(deformed iris, deformed pupils, semi-realistic, cgi, 3d, render, sketch, cartoon, drawing, anime:1.4), text, close up, cropped, out of frame, worst quality, low quality, jpeg artifacts, ugly, duplicate, morbid, mutilated, extra fingers, mutated hands, poorly drawn hands, poorly drawn face, mutation, deformed, blurry, dehydrated, bad anatomy, bad proportions, extra limbs, cloned face, disfigured, gross proportions, malformed limbs, missing arms, missing legs, extra arms, extra legs, fused fingers, too many fingers, long neck"
    }
)
print(output)
# Out:
# ---------------------------------------------------------------------------
# ReplicateError                            Traceback (most recent call last)
# <ipython-input-6-805046f7cc03> in <cell line: 0>()
# ----> 1 output = replicate.run(
#       2     "mixinmax1990/realisitic-vision-v3-image-to-image:6eb633a82ab3e7a4417d0af2e84e24b4b419c76f86f6e837824d02ae6845dc81",
#       3     input={
#       4         "seed": 12,
#       5         "image": "https://replicate.delivery/pbxt/J6aXwu9asvIjho0aW81BMCsXK0mNfqjHPJPSoJ4nCT1WWQbh/AdobeStock_506038307.jpeg",
#
# /usr/local/lib/python3.11/dist-packages/replicate/client.py in run(self, ref, input, use_file_output, **params)
#     173         """
#     174
# --> 175         return run(self, ref, input, use_file_output=use_file_output, **params)
#     176
#     177     async def async_run(
#
# /usr/local/lib/python3.11/dist-packages/replicate/run.py in run(client, ref, input, use_file_output, **params)
#      44
# ...

# %%
pip install diffusers torch transformers pillow accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 54.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 42.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 80.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
from diffusers import DiffusionPipeline
pipe = DiffusionPipeline.from_pretrained("yisol/IDM-VTON")
# Out:
# model_index.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/504 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/12.0G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.94k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]

# %%
import torch
from diffusers import DiffusionPipeline
from PIL import Image

# Load the virtual try-on pipeline
pipe = DiffusionPipeline.from_pretrained("yisol/IDM-VTON").to("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# model_index.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/504 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/12.0G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.94k [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/8 [00:00<?, ?it/s]
# ...

# %%
# !rm -rf ~/.cache/huggingface/hub

# %%
import torch
from diffusers import DiffusionPipeline
from PIL import Image

# Load the virtual try-on pipeline
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = DiffusionPipeline.from_pretrained("Aeryphilo/VTON-model").to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# scheduler_config.json:   0%|          | 0.00/504 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# ...

# %%
import torch
from diffusers import DiffusionPipeline
from PIL import Image

# Load the virtual try-on pipeline
device = "cuda" if torch.cuda.is_available() else "cpu"
pipe = DiffusionPipeline.from_pretrained("ixarchakos/tryOffAnyone")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/ixarchakos/tryOffAnyone/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-7-a1c853f942d7> in <cell line: 0>()
#       5 # Load the virtual try-on pipeline
# ...

# %%
# Load the images
person_image = Image.open("/content/t-shirt.jpeg").convert("RGB")
cloth_image = Image.open("/content/image-wear.jpeg").convert("RGB")

# Generate the try-on result
result = pipe(person_image=person_image, clothing_image=cloth_image).images[0]

# Display the result
result.show()

# Save the generated image
result.save("output_tryon.jpg")

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("ixarchakos/tryOffAnyone")

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/ixarchakos/tryOffAnyone/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-3-fefeccadb859> in <cell line: 0>()
#       1 from diffusers import DiffusionPipeline
#       2
# ...

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("rizavelioglu/tryoffdiff")

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/rizavelioglu/tryoffdiff/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-4-ffa71f712062> in <cell line: 0>()
#       1 from diffusers import DiffusionPipeline
#       2
# ...

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("rizavelioglu/tryoffdiff")

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/rizavelioglu/tryoffdiff/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-7-ffa71f712062> in <cell line: 0>()
#       1 from diffusers import DiffusionPipeline
#       2
# ...

# %%
from huggingface_hub import login
login()

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("yisol/IDM-VTON-DC")

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/yisol/IDM-VTON-DC/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-9-f3ed302d9f03> in <cell line: 0>()
#       1 from diffusers import DiffusionPipeline
#       2
# ...

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("imaginairy/idm-vton-safetensors")

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
# Out:
# model_index.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/504 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.94k [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/8 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ...

# %%
from huggingface_hub import snapshot_download
snapshot_download(repo_id="imaginairy/idm-vton-safetensors", cache_dir="./idm_vton_model")
# Out:
# Fetching 37 files:   0%|          | 0/37 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# teaser2.png:   0%|          | 0.00/9.02M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/560 [00:00<?, ?B/s]
# teaser.png:   0%|          | 0.00/7.06M [00:00<?, ?B/s]
# model_final_162be9.pkl:   0%|          | 0.00/256M [00:00<?, ?B/s]
# parsing_lip.onnx:   0%|          | 0.00/267M [00:00<?, ?B/s]
# model_index.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# parsing_atr.onnx:   0%|          | 0.00/267M [00:00<?, ?B/s]
# model.fp32.safetensors:   0%|          | 0.00/2.53G [00:00<?, ?B/s]
# model.fp16.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# body_pose_model.fp16.safetensors:   0%|          | 0.00/105M [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/504 [00:00<?, ?B/s]
# body_pose_model.fp32.safetensors:   0%|          | 0.00/209M [00:00<?, ?B/s]
# ...

# %%
pipe = DiffusionPipeline.from_pretrained("./idm_vton_model")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-03cdfc6654c5> in <cell line: 0>()
# ----> 1 pipe = DiffusionPipeline.from_pretrained("./idm_vton_model")
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/diffusers/pipelines/pipeline_utils.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     765             logger.warning(warn_msg)
#     766
# --> 767         config_dict = cls.load_config(cached_folder)
#     768
#     769         # pop out "_ignore_files" as it is only needed for download
#
# ...

# %%
# !pip install diffusers transformers accelerate torch torchvision pillow huggingface_hub

# %%
from diffusers import DiffusionPipeline

# Load the model from the downloaded directory
pipe = DiffusionPipeline.from_pretrained("./idm_vton_model")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-e55d6c8382ac> in <cell line: 0>()
#       2
#       3 # Load the model from the downloaded directory
# ----> 4 pipe = DiffusionPipeline.from_pretrained("./idm_vton_model")
#
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     112             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     113
# --> 114         return fn(*args, **kwargs)
#     115
#     116     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/diffusers/pipelines/pipeline_utils.py in from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#     765             logger.warning(warn_msg)
#     766
# --> 767         config_dict = cls.load_config(cached_folder)
#     768
# ...

# %%
import os

# Check the contents of the model directory
print(os.listdir("./idm_vton_model"))
# Out:
# ['models--imaginairy--idm-vton-safetensors', '.locks']

# %%
import os

snapshot_path = "/content/idm_vton_model/models--yisol--IDM-VTON/snapshots/585a32e74aee241cbc0d0cc3ab21392ca58c916a"

for root, dirs, files in os.walk(snapshot_path):
    print(f"📂 {root}")
    for file in files:
        print(f"   - {file}")

# %%
import shutil

dir_path = "/content/idm_vton_model"
shutil.rmtree(dir_path)
print("Directory deleted successfully!")
# Out:
# Directory deleted successfully!

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("jasperai/Flux.1-dev-Controlnet-Upscaler")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/jasperai/Flux.1-dev-Controlnet-Upscaler/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-17-289be524e62f> in <cell line: 0>()
#       1 from diffusers import DiffusionPipeline
#       2
# ...

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("alimama-creative/FLUX.1-dev-Controlnet-Inpainting-Beta")

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/alimama-creative/FLUX.1-dev-Controlnet-Inpainting-Beta/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-18-46cf5d0c49f7> in <cell line: 0>()
# ...

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-classification", model="jinaai/jina-reranker-v2-base-multilingual", trust_remote_code=True)
# Out:
# config.json:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# configuration_xlm_roberta.py:   0%|          | 0.00/2.73k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/jina-reranker-v2-base-multilingual:
# - configuration_xlm_roberta.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_xlm_roberta.py:   0%|          | 0.00/43.8k [00:00<?, ?B/s]
# mha.py:   0%|          | 0.00/28.0k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/jina-reranker-v2-base-multilingual:
# - mha.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# block.py:   0%|          | 0.00/19.7k [00:00<?, ?B/s]
# mlp.py:   0%|          | 0.00/6.21k [00:00<?, ?B/s]
# ...

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("timbrooks/instruct-pix2pix")
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
from diffusers import DiffusionPipeline

# Load a virtual try-on model (IDM-VTON or TryOnDiffusion)
pipe = DiffusionPipeline.from_pretrained("deepfashion/tryondiffusion")
pipe.to("cuda")  # Move to GPU for faster inference
# Out:
# Couldn't connect to the Hub: 404 Client Error. (Request ID: Root=1-67e4e40e-673be2e232b553b3343c8d53;a3bab636-0fa2-4baf-8cc6-bc86cc8d25f1)
#
# Repository Not Found for url: https://huggingface.co/api/models/deepfashion/tryondiffusion.
# Please make sure you specified the correct `repo_id` and `repo_type`.
# If you are trying to access a private or gated repo, make sure you are authenticated..
# Will try to load from local cache.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# ...

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("ohicarip/sd-deepfashion-baseline-model")

# prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
# image = pipe(prompt).images[0]
# Out:
# model_index.json:   0%|          | 0.00/634 [00:00<?, ?B/s]
# Fetching 75 files:   0%|          | 0/75 [00:00<?, ?it/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# diffusion_pytorch_model.safetensors:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# ...

# %%
# Load the images
person_image = Image.open("/content/t-shirt.jpeg").convert("RGB")
cloth_image = Image.open("/content/image-wear.jpeg").convert("RGB")

# Generate the try-on result
result = pipe(person_image=person_image, clothing_image=cloth_image).images[0]

# Display the result
result.show()

# Save the generated image
result.save("output_tryon.jpg")

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("vipul319/try-on")
# Out:
# model_index.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/504 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.94k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/12.0G [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/8 [00:00<?, ?it/s]
# ...

# %%
from diffusers import DiffusionPipeline
pipe = DiffusionPipeline.from_pretrained("ninjaneural/IDM-VTON")
# Out:
# model_index.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# Fetching 20 files:   0%|          | 0/20 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/504 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.53G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.78G [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/492M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.94k [00:00<?, ?B/s]
# ...

# %%
from diffusers import DiffusionPipeline
pipe = DiffusionPipeline.from_pretrained("SpringAI/TryonSpringHD")
# Out:
# model_index.json:   0%|          | 0.00/788 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# special_tokens_map.json:   0%|          | 0.00/496 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/770 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/523 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/771 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/574k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/783 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.02k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/484 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/691 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/12.0G [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/8 [00:00<?, ?it/s]
# ...

# %%
from diffusers import DiffusionPipeline
pipe = DiffusionPipeline.from_pretrained("MnLgt/IDM-VTON")
# Out:
# model_index.json:   0%|          | 0.00/750 [00:00<?, ?B/s]
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/737 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:02<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:02<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/504 [00:02<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/472 [00:02<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.06M [00:02<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/460 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/725 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.94k [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/12.0G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/746 [00:02<?, ?B/s]
# ...

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("raghav-ailusion/vton")
# Out:
# model_index.json:   0%|          | 0.00/815 [00:00<?, ?B/s]
# Fetching 21 files:   0%|          | 0/21 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/657 [00:00<?, ?B/s]
# scheduler_config.json:   0%|          | 0.00/648 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/582 [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/574k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.39G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.26G [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/496 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/667 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/734 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.11k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/484 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/893 [00:00<?, ?B/s]
# ...

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("mauriziopapa/try-on")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     408     try:
# --> 409         response.raise_for_status()
#     410     except HTTPError as e:
#
# /usr/local/lib/python3.11/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# -> 1024             raise HTTPError(http_error_msg, response=self)
#    1025
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/mauriziopapa/try-on/resolve/main/model_index.json
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# <ipython-input-42-69a05350507f> in <cell line: 0>()
#       1 from diffusers import DiffusionPipeline
#       2
# ...

# %%
# !rm -rf ~/.cache/huggingface
